# %% [markdown]
# ### **1. Library Importing**

# %%
import pandas as pd
import sqlalchemy as sa
from IPython.display import Image

# %% [markdown]
# ### **2. Inserting into SQL**

# %%
# Connecting to my local server
server = 'LAPTOP-3RLVA8MK\\SQLEXPRESS'
database = 'Metro_Network_Analysis'

connection_uri = f"mssql+pyodbc://@{server}/{database}?driver=ODBC+Driver+17+for+SQL+Server"
engine = sa.create_engine(connection_uri)
conn = engine.connect()

# %%
# Reading Metro data processed from data_processing.ipynb
metro_data = pd.read_csv('C:\\Users\\Blina Smailaj\\Documents\\GitHub\MetroNetworkAnalysis\\preprocessed_data\\Delhi-Metro-Network.csv')
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\M'
# <>:2: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\Blina Smailaj\AppData\Local\Temp\ipykernel_16960\4005695361.py:2: SyntaxWarning: invalid escape sequence '\M'
#   metro_data = pd.read_csv('C:\\Users\\Blina Smailaj\\Documents\\GitHub\MetroNetworkAnalysis\\preprocessed_data\\Delhi-Metro-Network.csv')

# %%
# Inserting data into sql
table_name = 'Metro_Station'
metro_data.to_sql(table_name, con=conn, if_exists='replace', index=False)
conn.close()

# %%
print("------------------------------  Result from SQL statement: select * from Metro_Station  ------------------------------")
Image(filename='select_stmt.png')
# Out:
# ------------------------------  Result from SQL statement: select * from Metro_Station  ------------------------------

# %% [markdown]
# End of **inserting_into_sql.ipynb.**
#
# - For processing the data go to  **"data_processing.ipynb"**
#
# - For conditional formatting go to  **"excel\excel_writer.ipynb"**
#
# - To see finished processed data go to **preprocessed_data\Delhi-Metro-Network.csv**
#
# - To see formatted excel file go to **excel\Delhi-Metro-Network-Formatted.csv**
